# %% [markdown]
# # Setup

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# GitHub-Daten einlesen
base_url = "https://raw.githubusercontent.com/opencampus-sh/einfuehrung-in-data-science-und-ml/main/"
df_umsatz = pd.read_csv(base_url + "umsatzdaten_gekuerzt.csv")
df_wetter = pd.read_csv(base_url + "wetter.csv")
df_kiwo = pd.read_csv(base_url + "kiwo.csv")

df_umsatz['Datum'] = pd.to_datetime(df_umsatz['Datum'])
df_wetter['Datum'] = pd.to_datetime(df_wetter['Datum'])
df_kiwo['Datum'] = pd.to_datetime(df_kiwo['Datum'])

# Mergen & Feature Engineering
df = df_umsatz.merge(df_wetter, on='Datum', how='left')
df = df.merge(df_kiwo, on='Datum', how='left')
df['KielerWoche'] = df['KielerWoche'].fillna(0).astype(int)
df['Wochentag'] = df['Datum'].dt.dayofweek
df['Monat'] = df['Datum'].dt.month
df['IstWochenende'] = df['Wochentag'].isin([5, 6]).astype(int)

# %% [markdown]
# # Überblick

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9334 entries, 0 to 9333
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   9334 non-null   int64
#  1   Datum                9334 non-null   datetime64[ns]
#  2   Warengruppe          9334 non-null   int64
#  3   Umsatz               9334 non-null   float64
#  4   Bewoelkung           9264 non-null   float64
#  5   Temperatur           9318 non-null   float64
#  6   Windgeschwindigkeit  9318 non-null   float64
#  7   Wettercode           7009 non-null   float64
#  8   KielerWoche          9334 non-null   int64
#  9   Wochentag            9334 non-null   int32
#  10  Monat                9334 non-null   int32
#  11  IstWochenende        9334 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int32(2), int64(4)
# memory usage: 802.3 KB

# %% [markdown]
# # Statistiken

# %%
df.describe().T
# Out:
#                       count                           mean  \
# id                   9334.0                 1559311.249732
# Datum                  9334  2016-01-13 23:56:27.100921344
# Warengruppe          9334.0                       3.088172
# Umsatz               9334.0                     206.749044
# Bewoelkung           9264.0                       4.720747
# Temperatur           9318.0                      12.028483
# Windgeschwindigkeit  9318.0                       10.97478
# Wettercode           7009.0                      36.900128
# KielerWoche          9334.0                       0.023891
# Wochentag            9334.0                       3.000536
# Monat                9334.0                        6.65481
# IstWochenende        9334.0                       0.286908
#
#                                      min                  25%  \
# id                             1307011.0           1410123.25
# Datum                2013-07-01 00:00:00  2014-10-12 00:00:00
# Warengruppe                          1.0                  2.0
# Umsatz                          7.051201            96.897441
# Bewoelkung                           0.0                  3.0
# Temperatur                        -8.475               6.2375
# Windgeschwindigkeit                  3.0                  8.0
# Wettercode                           0.0                 10.0
# KielerWoche                          0.0                  0.0
# Wochentag                            0.0                  1.0
# Monat                                1.0                  4.0
# IstWochenende                        0.0                  0.0
#
#                                      50%                  75%  \
# id                             1601102.5           1704222.75
# Datum                2016-01-10 00:00:00  2017-04-22 00:00:00
# Warengruppe                          3.0                  4.0
# Umsatz                        161.900831           280.644663
# Bewoelkung                           6.0                  7.0
# Temperatur                        11.625              17.9625
# Windgeschwindigkeit                 10.0                 13.0
# Wettercode                          28.0                 61.0
# KielerWoche                          0.0                  0.0
# Wochentag                            3.0                  5.0
# Monat                                7.0                 10.0
# IstWochenende                        0.0                  1.0
#
#                                      max            std
# id                             1807315.0  151250.254673
# Datum                2018-07-31 00:00:00            NaN
# Warengruppe                          6.0       1.489002
# Umsatz                       1879.461831     144.545189
# Bewoelkung                           8.0       2.646273
# Temperatur                       31.4375       7.232829
# Windgeschwindigkeit                 35.0       4.131974
# Wettercode                          95.0      27.095884
# KielerWoche                          1.0       0.152718
# Wochentag                            6.0       2.001044
# Monat                               12.0       3.461902
# IstWochenende                        1.0       0.452343

# %% [markdown]
# # Visualisierung fehlender Werte

# %%
msno.matrix(df)
plt.show()

# %% [markdown]
# # Histogramm Umsatz

# %%
sns.histplot(df['Umsatz'], bins=50, kde=True)
plt.title("Verteilung des Umsatzes")
plt.xlabel("Umsatz")
plt.ylabel("Häufigkeit")
plt.show()
